# %%
import os
os.chdir("../")

# %%
from pathlib import Path
from pydantic import BaseModel,HttpUrl

class ModelTrainerConfig(BaseModel):
    ## from config
    root_dir: Path
    train_data_path: Path
    test_data_path: Path
  
    mlflow_uri: HttpUrl
    mlflow_experiment: str
    standard_scaler_name: str
    
    ## from params
    models: list
    hyperparams: dict

    ## from schema 
    target_column: str

# %%
from src.NetworkSecurity.constants import *
from src.NetworkSecurity.utils.common import read_yaml,create_directories

class ConfigurationManager:
    def __init__(self,
                 config_filepath = CONFIG_FILE_PATH,
                 params_filepath = PARAMS_FILE_PATH,
                 schema_filepath = SCHEMA_FILE_PATH):
        
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])
    
    def get_model_trainer_config(self)->ModelTrainerConfig:

        config = self.config.model_trainer
        params = self.params.model_trainer
        schema = self.schema.TARGET_COLUMN

        create_directories([config.root_dir])

        model_trainer_config = ModelTrainerConfig(
            root_dir = config.root_dir,
            train_data_path = config.train_data_path,
            test_data_path = config.test_data_path,
            mlflow_uri = config.mlflow_uri,
            mlflow_experiment = config.mlflow_experiment,
            standard_scaler_name = config.standard_scaler_name,

            models = list(params.model.keys()),
            hyperparams = params.model.to_dict(),
            
            target_column = schema.name           
        )

        return model_trainer_config

# %%
cm = ConfigurationManager()
model_trainer_config = cm.get_model_trainer_config()
# Out:
# [2025-12-11 09:10:00,583: INFO: common : Yaml File: config/config.yaml loaded successfully]
# [2025-12-11 09:10:00,589: INFO: common : Yaml File: params.yaml loaded successfully]
# [2025-12-11 09:10:00,596: INFO: common : Yaml File: schema.yaml loaded successfully]
# [2025-12-11 09:10:00,597: INFO: common : created directory at: artifacts]
# [2025-12-11 09:10:00,597: INFO: common : created directory at: artifacts/model_trainer]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from src.NetworkSecurity.logging.logger import logger
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
import mlflow
from sklearn.preprocessing import StandardScaler
import pickle
from urllib.parse import urlparse
from mlflow.models import infer_signature
from sklearn.model_selection import GridSearchCV
from dotenv import load_dotenv
import datetime
import os
from src.NetworkSecurity.entity.config_entity import ModelTrainerConfig

load_dotenv()

class ModelTrainer:
    def __init__(self,config: ModelTrainerConfig):
        self.config = config
        os.environ["MLFLOW_TRACKING_USERNAME"] = os.getenv("MLFLOW_TRACKING_USERNAME")
        os.environ["MLFLOW_TRACKING_PASSWORD"] = os.getenv("MLFLOW_TRACKING_PASSWORD")
    
    def train(self):

        train_data = pd.read_csv(self.config.train_data_path)
        test_data = pd.read_csv(self.config.test_data_path)

        # Split features & target
        x_train = train_data.drop(columns=[self.config.target_column], axis=1)
        y_train = train_data[self.config.target_column]
        x_test = test_data.drop(columns=[self.config.target_column], axis=1)
        y_test = test_data[self.config.target_column]

        model_mapping = {
            "LogisticRegression": LogisticRegression(),
            "DecisionTreeClassifier": DecisionTreeClassifier(),
            "GradientBoostingClassifier": GradientBoostingClassifier(),
            "AdaBoostClassifier": AdaBoostClassifier(),
            "KNeighborsClassifier": KNeighborsClassifier(),
            "SVC": SVC(),
            "XGBClassifier": XGBClassifier(),
        }

        # Standardize features
        ss = StandardScaler()
        x_train = ss.fit_transform(x_train)

        # Standardize test features
        x_test = ss.transform(x_test)

        scaler_path = os.path.join(self.config.root_dir, self.config.standard_scaler_name)
        with open(scaler_path, "wb") as f:
            pickle.dump(ss, f)

        models = self.config.models
        hyperparams = self.config.hyperparams

        best_model = None
        best_score = -float("inf")

        # MLflow setup

        mlflow.set_tracking_uri(str(self.config.mlflow_uri))  # Use this for tracking runs
        mlflow.set_registry_uri(str(self.config.mlflow_uri))  # Use the same URI for model registry
        mlflow.set_experiment(self.config.mlflow_experiment)
        tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme
        signature = infer_signature(x_train, y_train)

        for model_name in models:
            model = model_mapping[model_name]
            params = hyperparams.get(model_name, {})

            grid_search = GridSearchCV(model, param_grid=params, cv=5, scoring="accuracy", n_jobs=-1)
            grid_search.fit(x_train, y_train)

            for param, score in zip(grid_search.cv_results_["params"], grid_search.cv_results_["mean_test_score"]):
                with mlflow.start_run():
                    print(f"{param}: {score:.4f}")

                    mlflow.log_params(param)  
                    mlflow.log_metric("train_accuracy", f"{score:.4f}")
                    mlflow.log_param("model_name", model_name)

                    # Track best model based on training accuracy (since GridSearchCV only works on train)
                    if score > best_score:  
                        best_score = score  
                        best_model = grid_search.best_estimator_  
                        best_param = param 
                        best_model_name = model_name 

        # Now test the best model on the test set
        test_acc = best_model.score(x_test, y_test)

        
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
        model_filename = f"{self.config.root_dir}/{best_model_name}_{timestamp}.pkl"

        # Save the best model
        with open(model_filename, "wb") as f:
            pickle.dump(best_model, f)

        # Save metadata (best parameters)
        metadata_filename = f"{self.config.root_dir}/{best_model_name}_{timestamp}_metadata.txt"
        with open(metadata_filename, "w") as f:
            f.write(f"Model: {best_model_name}\n")
            f.write(f"Best Params: {best_param}\n")
            f.write(f"Train Accuracy: {best_score}\n")

        # Log the best model based on test accuracy
        with mlflow.start_run():
            mlflow.log_params(best_param)
            mlflow.log_metric("test_accuracy", f"{test_acc:.4f}")  # Now test accuracy is logged
            mlflow.log_param("model_name",best_model_name)

            if tracking_url_type_store != "file":
                mlflow.sklearn.log_model(best_model, "model", registered_model_name="Best Model", signature=signature)
            else:
                mlflow.sklearn.log_model(best_model, "model", signature=signature)

# %%
mt = ModelTrainer(model_trainer_config)
mt.train()
# Out:
# 2025/12/11 09:10:11 INFO mlflow.tracking.fluent: Experiment with name 'Model_training' does not exist. Creating a new experiment.
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}: 0.9256
# 🏃 View run peaceful-lamb-226 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/5bc6d2b477214debb15ca8152c6770f3
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}: 0.9263
# 🏃 View run efficient-goat-708 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/7cd61fc2a1bb4e4db4f7cace6f6fa138
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}: 0.9347
# 🏃 View run intrigued-deer-569 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/d1ff6aa294ad463d99473c1b8fefd454
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.01, 'penalty': 'l2', 'solver': 'saga'}: 0.9346
# 🏃 View run monumental-koi-392 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/8667b0c45ee14ccea901a36356beac6b
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}: 0.9404
# 🏃 View run lyrical-rat-461 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/7314720e2fee43dca1593bc2dbc3d2fe
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}: 0.9400
# 🏃 View run gregarious-croc-148 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/4efab861c0b64531a7d2e884bfc48568
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}: 0.9404
# 🏃 View run capricious-gnat-264 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/ae03694e50b74d35b432055fe1107eda
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.1, 'penalty': 'l2', 'solver': 'saga'}: 0.9398
# 🏃 View run treasured-whale-373 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/bef2bb62e0974774987535b9547d10a7
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}: 0.9440
# 🏃 View run luxuriant-carp-264 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/3c1903f2a0b441f7b128ac30187cec40
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 1, 'penalty': 'l1', 'solver': 'saga'}: 0.9406
# 🏃 View run bemused-kite-967 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs
at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/e3587aa6455148cfa9c959af9e940b8a
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# 2025/12/11 09:33:31 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run languid-moth-60 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/3ef5826412ff48cc9fb13bc0b6c10a3c
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[6], line 2
#       1 mt = ModelTrainer(model_trainer_config)
# ----> 2 mt.train()
#
# Cell In[5], line 122, in ModelTrainer.train(self)
#     119 mlflow.log_param("model_name",best_model_name)
#     121 if tracking_url_type_store != "file":
# --> 122     mlflow.sklearn.log_model(best_model, "model", registered_model_name="Best Model", signature=signature)
#     123 else:
#     124     mlflow.sklearn.log_model(best_model, "model", signature=signature)
#
# File ~/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/mlflow/sklearn/__init__.py:426, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata, params, tags, model_type, step, model_id, name)
#     334 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     335 def log_model(
#     336     sk_model,
#    (...)
#     355     name: str | None = None,
#     356 ):
#     357     """
#     358     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     359     containing the following flavors:
#    (...)
#     424
#     425     """
# --> 426     return Model.log(
#     427         artifact_path=artifact_path,
#     428         name=name,
#     429         flavor=mlflow.sklearn,
#     430         sk_model=sk_model,
#     431         conda_env=conda_env,
#     432         code_paths=code_paths,
#     433         serialization_format=serialization_format,
#     434         registered_model_name=registered_model_name,
#     435         signature=signature,
#     436         input_example=input_example,
#     437         await_registration_for=await_registration_for,
#     438         pip_requirements=pip_requirements,
#     439         extra_pip_requirements=extra_pip_requirements,
#     440         pyfunc_predict_fn=pyfunc_predict_fn,
#     441         metadata=metadata,
#     442         params=params,
#     443         tags=tags,
#     444         model_type=model_type,
#     445         step=step,
#     446         model_id=model_id,
#     447     )
#
# File ~/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/mlflow/models/model.py:1162, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, auth_policy, prompts, name, model_type, params, tags, step, model_id, **kwargs)
#    1160 if flavor_name is None:
#    1161     flavor_name = flavor.__name__ if hasattr(flavor, "__name__") else "custom"
# -> 1162 model = _create_logged_model(
#    1163     # TODO: Update model name
#    1164     name=name,
#    1165     source_run_id=run_id,
#    1166     model_type=model_type,
#    1167     params={key: str(value) for key, value in params.items()},
#    1168     tags={key: str(value) for key, value in tags.items()}
#    1169     if tags is not None
#    1170     else None,
#    1171     flavor=flavor_name,
#    1172 )
#    1173 _last_logged_model_id.set(model.model_id)
#    1174 if (
#    1175     MLFLOW_PRINT_MODEL_URLS_ON_CREATION.get()
#    1176     and is_databricks_uri(tracking_uri)
#    1177     and (workspace_url := get_workspace_url())
#    1178 ):
#
# File ~/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/mlflow/tracking/fluent.py:2408, in _create_logged_model(name, source_run_id, tags, params, model_type, experiment_id, flavor)
#    2404     experiment_id = _get_experiment_id() or (
#    2405         get_run(source_run_id).info.experiment_id if source_run_id else None
#    2406     )
#    2407 resolved_tags = context_registry.resolve_tags(tags)
# -> 2408 return MlflowClient()._create_logged_model(
#    2409     experiment_id=experiment_id,
#    2410     name=name,
#    2411     source_run_id=source_run_id,
#    2412     tags=resolved_tags,
#    2413     params=params,
#    2414     model_type=model_type,
#    2415     flavor=flavor,
#    2416 )
#
# File ~/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/mlflow/tracking/client.py:5556, in MlflowClient._create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type, flavor)
#    5546 def _create_logged_model(
#    5547     self,
#    5548     experiment_id: str,
#    (...)
#    5554     flavor: str | None = None,
#    5555 ) -> LoggedModel:
# -> 5556     return self._tracking_client.create_logged_model(
#    5557         experiment_id, name, source_run_id, tags, params, model_type, flavor
#    5558     )
#
# File ~/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/mlflow/telemetry/track.py:24, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      21 @functools.wraps(func)
#      22 def wrapper(*args: P.args, **kwargs: P.kwargs) -> R:
#      23     if is_telemetry_disabled() or _is_telemetry_disabled_for_event(event):
# ---> 24         return func(*args, **kwargs)
#      26     success = True
#      27     result = None
#
# File ~/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:870, in TrackingServiceClient.create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type, flavor)
#     857 @record_usage_event(CreateLoggedModelEvent)
#     858 def create_logged_model(
#     859     self,
#    (...)
#     868     flavor: str | None = None,
#     869 ) -> LoggedModel:
# --> 870     return self.store.create_logged_model(
#     871         experiment_id=experiment_id,
#     872         name=name,
#     873         source_run_id=source_run_id,
#     874         tags=[LoggedModelTag(str(key), str(value)) for key, value in tags.items()]
#     875         if tags is not None
#     876         else tags,
#     877         params=[LoggedModelParameter(str(key), str(value)) for key, value in params.items()]
#     878         if params is not None
#     879         else params,
#     880         model_type=model_type,
#     881     )
#
# File ~/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/mlflow/store/tracking/rest_store.py:956, in RestStore.create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type)
#     943     remaining_params = params[initial_batch_size:]
#     945 req_body = message_to_json(
#     946     CreateLoggedModel(
#     947         experiment_id=experiment_id,
#    (...)
#     953     )
#     954 )
# --> 956 response_proto = self._call_endpoint(CreateLoggedModel, req_body)
#     957 model = LoggedModel.from_proto(response_proto.model)
#     959 # Log remaining params if there are any
#
# File ~/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/mlflow/store/tracking/rest_store.py:208, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     206     endpoint, method = self._METHOD_TO_INFO[api]
#     207 response_proto = response_proto or api.Response()
# --> 208 return call_endpoint(
#     209     self.get_host_creds(),
#     210     endpoint,
#     211     method,
#     212     json_body,
#     213     response_proto,
#     214     retry_timeout_seconds=retry_timeout_seconds,
#     215 )
#
# File ~/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/mlflow/utils/rest_utils.py:596, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     593     call_kwargs["json"] = json_body
#     594     response = http_request(**call_kwargs)
# --> 596 response = verify_rest_response(response, endpoint)
#     597 response_to_parse = response.text
#     598 try:
#
# File ~/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/mlflow/utils/rest_utils.py:315, in verify_rest_response(response, endpoint)
#     313 if response.status_code != 200:
#     314     if _can_parse_as_json_object(response.text):
# --> 315         raise RestException(json.loads(response.text))
#     316     else:
#     317         base_msg = (
#     318             f"API request to endpoint {endpoint} "
#     319             f"failed with error code {response.status_code} != 200"
#     320         )
#
# RestException: INTERNAL_ERROR: Response: {'error': 'unsupported endpoint, please contact support@dagshub.com'}
