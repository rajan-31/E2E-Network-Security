# %%
import os
os.chdir("../")

# %%
from pathlib import Path
from pydantic import BaseModel,HttpUrl

class ModelTrainerConfig(BaseModel):
    ## from config
    root_dir: Path
    train_data_path: Path
    test_data_path: Path
  
    mlflow_uri: HttpUrl
    mlflow_experiment: str
    standard_scaler_name: str
    
    ## from params
    models: list
    hyperparams: dict

    ## from schema 
    target_column: str

# %%
from src.NetworkSecurity.constants import *
from src.NetworkSecurity.utils.common import read_yaml,create_directories

class ConfigurationManager:
    def __init__(self,
                 config_filepath = CONFIG_FILE_PATH,
                 params_filepath = PARAMS_FILE_PATH,
                 schema_filepath = SCHEMA_FILE_PATH):
        
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])
    
    def get_model_trainer_config(self)->ModelTrainerConfig:

        config = self.config.model_trainer
        params = self.params.model_trainer
        schema = self.schema.TARGET_COLUMN

        create_directories([config.root_dir])

        model_trainer_config = ModelTrainerConfig(
            root_dir = config.root_dir,
            train_data_path = config.train_data_path,
            test_data_path = config.test_data_path,
            mlflow_uri = config.mlflow_uri,
            mlflow_experiment = config.mlflow_experiment,
            standard_scaler_name = config.standard_scaler_name,

            models = list(params.model.keys()),
            hyperparams = params.model.to_dict(),
            
            target_column = schema.name           
        )

        return model_trainer_config

# %%
cm = ConfigurationManager()
model_trainer_config = cm.get_model_trainer_config()
# Out:
# [2025-12-12 00:11:27,581: INFO: common : Yaml File: config/config.yaml loaded successfully]
# [2025-12-12 00:11:27,590: INFO: common : Yaml File: params.yaml loaded successfully]
# [2025-12-12 00:11:27,598: INFO: common : Yaml File: schema.yaml loaded successfully]
# [2025-12-12 00:11:27,599: INFO: common : created directory at: artifacts]
# [2025-12-12 00:11:27,600: INFO: common : created directory at: artifacts/model_trainer]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from src.NetworkSecurity.logging.logger import logger
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
import mlflow
from sklearn.preprocessing import StandardScaler
import pickle
from urllib.parse import urlparse
from mlflow.models import infer_signature
from sklearn.model_selection import GridSearchCV
from dotenv import load_dotenv
import datetime
import os
from src.NetworkSecurity.entity.config_entity import ModelTrainerConfig

load_dotenv()

class ModelTrainer:
    def __init__(self,config: ModelTrainerConfig):
        self.config = config
        os.environ["MLFLOW_TRACKING_USERNAME"] = os.getenv("MLFLOW_TRACKING_USERNAME")
        os.environ["MLFLOW_TRACKING_PASSWORD"] = os.getenv("MLFLOW_TRACKING_PASSWORD")
    
    def train(self):

        train_data = pd.read_csv(self.config.train_data_path)
        test_data = pd.read_csv(self.config.test_data_path)

        # Split features & target
        x_train = train_data.drop(columns=[self.config.target_column], axis=1)
        y_train = train_data[self.config.target_column]
        x_test = test_data.drop(columns=[self.config.target_column], axis=1)
        y_test = test_data[self.config.target_column]

        model_mapping = {
            "LogisticRegression": LogisticRegression(),
            "DecisionTreeClassifier": DecisionTreeClassifier(),
            "GradientBoostingClassifier": GradientBoostingClassifier(),
            "AdaBoostClassifier": AdaBoostClassifier(),
            "KNeighborsClassifier": KNeighborsClassifier(),
            "SVC": SVC(),
            "XGBClassifier": XGBClassifier(),
        }

        # Standardize features
        ss = StandardScaler()
        x_train = ss.fit_transform(x_train)

        # Standardize test features
        x_test = ss.transform(x_test)

        scaler_path = os.path.join(self.config.root_dir, self.config.standard_scaler_name)
        with open(scaler_path, "wb") as f:
            pickle.dump(ss, f)

        models = self.config.models
        hyperparams = self.config.hyperparams

        best_model = None
        best_score = -float("inf")

        # MLflow setup

        mlflow.set_tracking_uri(str(self.config.mlflow_uri))  # Use this for tracking runs
        mlflow.set_registry_uri(str(self.config.mlflow_uri))  # Use the same URI for model registry
        mlflow.set_experiment(self.config.mlflow_experiment)
        tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme
        signature = infer_signature(x_train, y_train)

        for model_name in models:
            model = model_mapping[model_name]
            params = hyperparams.get(model_name, {})

            grid_search = GridSearchCV(model, param_grid=params, cv=5, scoring="accuracy", n_jobs=-1)
            grid_search.fit(x_train, y_train)

            for param, score in zip(grid_search.cv_results_["params"], grid_search.cv_results_["mean_test_score"]):
                with mlflow.start_run():
                    print(f"{param}: {score:.4f}")

                    mlflow.log_params(param)  
                    mlflow.log_metric("train_accuracy", f"{score:.4f}")
                    mlflow.log_param("model_name", model_name)

                    # Track best model based on training accuracy (since GridSearchCV only works on train)
                    if score > best_score:  
                        best_score = score  
                        best_model = grid_search.best_estimator_  
                        best_param = param 
                        best_model_name = model_name 

        # Now test the best model on the test set
        test_acc = best_model.score(x_test, y_test)

        
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
        model_filename = f"{self.config.root_dir}/{best_model_name}_{timestamp}.pkl"

        # Save the best model
        with open(model_filename, "wb") as f:
            pickle.dump(best_model, f)

        # Save metadata (best parameters)
        metadata_filename = f"{self.config.root_dir}/{best_model_name}_{timestamp}_metadata.txt"
        with open(metadata_filename, "w") as f:
            f.write(f"Model: {best_model_name}\n")
            f.write(f"Best Params: {best_param}\n")
            f.write(f"Train Accuracy: {best_score}\n")

        # Log the best model based on test accuracy
        with mlflow.start_run():
            mlflow.log_params(best_param)
            mlflow.log_metric("test_accuracy", f"{test_acc:.4f}")  # Now test accuracy is logged
            mlflow.log_param("model_name",best_model_name)

            if tracking_url_type_store != "file":
                mlflow.sklearn.log_model(best_model, "model", registered_model_name="Best Model", signature=signature)
            else:
                mlflow.sklearn.log_model(best_model, "model", signature=signature)

# %%
mt = ModelTrainer(model_trainer_config)
mt.train()
# Out:
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/rajan/0.Projects/SPE-final-project/.e2e_nw_sec/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}: 0.9256
# 🏃 View run gaudy-roo-683 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/19b82423a7994045bb2d84994ab7999c
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}: 0.9263
# 🏃 View run delightful-snipe-257 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/46143fdc02e645468824973cc6701cc5
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}: 0.9347
# 🏃 View run melodic-turtle-65 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/5a021fc328354e1d8e52dbc212668589
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.01, 'penalty': 'l2', 'solver': 'saga'}: 0.9346
# 🏃 View run legendary-grouse-709 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/4b8ec6469b0b40c787fe60a239d9b193
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}: 0.9405
# 🏃 View run thundering-skunk-892 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/f5867f5a99cd466db50599ff1df90ccb
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}: 0.9400
# 🏃 View run stylish-bass-396 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/db8d90dc4eae43b98331c802a13864f0
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}: 0.9404
# 🏃 View run serious-croc-960 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/f60dbfb59d5e411ba0ac1f996e80f683
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 0.1, 'penalty': 'l2', 'solver': 'saga'}: 0.9398
# 🏃 View run grandiose-crow-272 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/5bd7cf4fcabb4adc84dee330ba9247f7
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}: 0.9441
# 🏃 View run defiant-tern-615 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/d595c9264f334126a0ad1ac9f0c5e5be
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'C': 1, 'penalty': '

# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100, 'subsample': 0.6}: 0.9711
# 🏃 View run bustling-steed-385 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/9eb068e68e894195b29d4f7574263ad8
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100, 'subsample': 0.8}: 0.9729
# 🏃 View run resilient-chimp-771 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/1e65621db98b456a9e3713f483f30b6e
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100, 'subsample': 1.0}: 0.9749
# 🏃 View run omniscient-ape-524 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/8515456a8bd644ce8d95cd07a51a0d86
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 200, 'subsample': 0.6}: 0.9751
# 🏃 View run languid-ray-370 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/c77511d2373340b88556acf69adaa132
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 200, 'subsample': 0.8}: 0.9766
# 🏃 View run stately-smelt-623 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/9e6412b0a2e345938520f5480960af87
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 200, 'subsample': 1.0}: 0.9764
# 🏃 View run serious-bird-652 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/724aa092e2124f44b0da9c5ddced53dc
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.6}: 0.9680
# 🏃 View run bedecked-grouse-972 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/f130c7d051f94842aadb84b1dbfa902b
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}: 0.9675
# 🏃 View run rambunctious-toad-60 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/bb6284bce5fb48e3bc2a61066dad585c
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0}: 0.9676
# 🏃 View run persistent-vole-623 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/0a5878fb98a342419073faf55dd8f154
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.6}: 0.9775
# 🏃 View run indecisive-moose-827 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/56915a5b9771483ba8509fb97619f916
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}: 0.9770
# 🏃 View run dazzling-turtle-687 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/864e1ecf41e74a209669f97710018d6f
# ...
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8}: 0.9821
# 🏃 View run stylish-boar-372 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/70856540baac4069b846dd60fa2b4daa
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0}: 0.9815
# 🏃 View run incongruous-pug-718 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/23de504908264c2da21a98ccfdf31c75
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.6}: 0.9789
# 🏃 View run learned-hen-835 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/19ae28163ad4463d9717c3620f3c737c
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8}: 0.9785
# 🏃 View run flawless-wasp-326 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/ef0ea9b0e3834f9d8f6ef1cff337dfa5
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0}: 0.9778
# 🏃 View run rare-squirrel-267 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/3d854a30ea624807b09d39d671f13170
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.6}: 0.9844
# 🏃 View run rumbling-shrike-967 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/cfdd55b7088a4021977824cf10d613c6
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8}: 0.9854
# 🏃 View run exultant-conch-653 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/9f4fee2f9235474ab1120041cd01eb23
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0}: 0.9835
# 🏃 View run glamorous-mare-941 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/6035389f8a204592a6e8338a5f9ee92a
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.6}: 0.9852
# 🏃 View run monumental-elk-218 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/7c5cdd91fed04bd7bc6d1cfdc43e4f4c
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8}: 0.9866
# 🏃 View run intelligent-fox-812 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/c5ff9f4e56de4077b2e279097a2e42b3
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'subsample': 1.0}: 0.9848
# 🏃 View run victorious-smelt-249 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/1577b11d1d7d420b96b77646ac936448
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'subsample': 0.6}: 0.9805
# 🏃 View run glamorous-steed-93 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/78e51cccbd074cb3b23b7d09a1b5be58
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'subsample': 0.8}: 0.9831
# 🏃 View run merciful-snail-618 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/c78283c2660c45d5b3c14591c48e5295
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'subsample': 1.0}: 0.9821
# 🏃 View run calm-shrike-805 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/e5e4cb08189847f09e5b3ea8570c1e42
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'subsample': 0.6}: 0.9849
# 🏃 View run aged-mouse-939 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/e37f09bbc38c49eca6a0c27578a5c850
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'subsample': 0.8}: 0.9859
# 🏃 View run adventurous-koi-77 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/da9c6355decd4f4b8d387fa955b5fac3
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'subsample': 1.0}: 0.9853
# 🏃 View run stylish-pug-736 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/512ee8edf8394d47b3d0efc231c6b06a
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200, 'subsample': 0.6}: 0.9852
# 🏃 View run blushing-fish-683 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/598d629fcfea45be86e074854f2b6915
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200, 'subsample': 0.8}: 0.9865
# 🏃 View run bright-sloth-767 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/1a3feff4ee0049469992cba941753014
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200, 'subsample': 1.0}: 0.9858
# 🏃 View run omniscient-stork-43 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/128c913cfa0a43d4bafbe5bea9168372
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.6}: 0.9780
# 🏃 View run youthful-snail-586 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/bc1d4988f2aa423ab3e047e419cef950
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8}: 0.9786
# 🏃 View run persistent-toad-57 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/1b855a4051fa4da9a2c9658073567dd3
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0}: 0.9776
# 🏃 View run bedecked-pig-398 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/d017b5180cf04485aab456ad4a0ef30d
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.6}: 0.9828
# 🏃 View run blushing-snail-807 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/d40cec7de763483c9fbe45e324698e2f
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}: 0.9839
# 🏃 View run popular-shrike-962 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/7991553988344ac1a9f77b882fde7960
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}: 0.9820
# 🏃 View run casual-pug-611 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/063d988767794dcba7143e8949b2e92b
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.6}: 0.9840
# 🏃 View run debonair-grouse-617 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/b51e9f777c994d538f5299cc4e495a03
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8}: 0.9850
# 🏃 View run learned-newt-766 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/e40136c3c48e4072a81f0706a5dcfbc9
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0}: 0.9845
# 🏃 View run big-flea-516 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/829bcb99b178414faf89d71e220c9747
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.6}: 0.9840
# 🏃 View run serious-boar-539 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/3e008f4b9bc64e1282555c9a0c1c385f
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8}: 0.9836
# 🏃 View run agreeable-rat-946 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/c75e9933990c49879ddd0f704d9344c3
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0}: 0.9839
# 🏃 View run learned-dog-506 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/13c5021bb1b8402c8ed743570dfd9032
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.6}: 0.9844
# 🏃 View run abrasive-midge-428 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/133e8745147e47a0bfc91359f3c7be56
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8}: 0.9865
# 🏃 View run amusing-roo-420 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/88a7743a015746cd96b43c15411fdb3f
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0}: 0.9850
# 🏃 View run orderly-snake-154 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/81177469d1394ca19a948cae62449391
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.6}: 0.9856
# 🏃 View run luxuriant-midge-160 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/f33c6ada627b486e92220cc3f7cf2018
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8}: 0.9861
# 🏃 View run likeable-sloth-1000 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/453386bf059b47359d1fa7abe3797e59
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 200, 'subsample': 1.0}: 0.9856
# 🏃 View run stylish-owl-332 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/7b19f02555ee4a859279db57be121f7f
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 50, 'subsample': 0.6}: 0.9853
# 🏃 View run able-crane-735 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/403837a8b6634e6ca961a99fe3f51f6f
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 50, 'subsample': 0.8}: 0.9852
# 🏃 View run dapper-skunk-816 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/790afe52815846eeadb001c79835860b
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 50, 'subsample': 1.0}: 0.9859
# 🏃 View run tasteful-grub-72 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/acbcc73c98bc439f8b1b85bee68a4019
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 100, 'subsample': 0.6}: 0.9856
# 🏃 View run gentle-eel-663 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/ce48362550ca4dbb9cc6935314988afd
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 100, 'subsample': 0.8}: 0.9869
# 🏃 View run persistent-perch-238 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/f549db04d35a41cca094e0ca5312596f
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 100, 'subsample': 1.0}: 0.9863
# 🏃 View run dashing-elk-417 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/c9f09e3fdc6147bdafa8ec1d0230320f
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 200, 'subsample': 0.6}: 0.9856
# 🏃 View run gifted-hound-725 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/c21fd97325c645f28362d7d154ba072d
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 200, 'subsample': 0.8}: 0.9877
# 🏃 View run tasteful-yak-343 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/49488bf380514fe18f95b8f6b9f74553
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# {'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 200, 'subsample': 1.0}: 0.9870
# 🏃 View run handsome-calf-172 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/96cae389d9c3412e86a45d5548e10cb2
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
# Registered model 'Best Model' already exists. Creating a new version of this model...
# 2025/12/12 00:35:50 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Best Model, version 4
# Created version '4' of model 'Best Model'.
# 🏃 View run stately-shrimp-451 at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0/runs/643eea5555fd44d5bdba6ea8e13f6cd6
# 🧪 View experiment at: https://dagshub.com/rajan-31/E2E-Network-Security.mlflow/#/experiments/0
